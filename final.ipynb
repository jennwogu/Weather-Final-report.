# %%
import pandas as pd
import seaborn as sns
sns.set(color_codes=True)

# %%
weather = pd.read_csv('Test.csv')

# %%
weather.head()
# Out:
#   Unnamed: 0         date_time is_holiday  air_pollution_index  humidity  \
# 0        NaN  18-05-2017 00:00       None                 73.0      63.0
# 1        NaN  18-05-2017 00:00       None                251.0      63.0
# 2        NaN  18-05-2017 00:00       None                 75.0      56.0
# 3        NaN  18-05-2017 01:00       None                 98.0      56.0
# 4        NaN  18-05-2017 01:00       None                283.0      56.0
#
#    wind_speed  wind_direction  visibility_in_miles  dew_point  temperature  \
# 0         1.0            27.0                  4.0        4.0       285.15
# 1         1.0            27.0                  4.0        4.0       285.15
# 2         1.0             0.0                  1.0        1.0       285.15
# 3         1.0           351.0                  2.0        2.0       284.79
# 4         1.0           351.0                  1.0        1.0       284.79
#
#    rain_p_h  snow_p_h  clouds_all weather_type      weather_description
# 0       0.0       0.0        90.0         Rain            moderate rain
# 1       0.0       0.0        90.0         Mist                     mist
# 2       0.0       0.0        90.0      Drizzle  light intensity drizzle
# 3       0.0       0.0        90.0         Rain     heavy intensity rain
# 4       0.0       0.0        90.0         Mist                     mist

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14471 entries, 0 to 14470
# Data columns (total 15 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           17 non-null     object
#  1   date_time            199 non-null    object
#  2   is_holiday           199 non-null    object
#  3   air_pollution_index  199 non-null    float64
#  4   humidity             199 non-null    float64
#  5   wind_speed           199 non-null    float64
#  6   wind_direction       199 non-null    float64
#  7   visibility_in_miles  199 non-null    float64
#  8   dew_point            199 non-null    float64
#  9   temperature          199 non-null    float64
#  10  rain_p_h             199 non-null    float64
#  11  snow_p_h             199 non-null    float64
#  12  clouds_all           199 non-null    float64
#  13  weather_type         199 non-null    object
#  14  weather_description  199 non-null    object
# dtypes: float64(10), object(5)
# memory usage: 1.7+ MB

# %%
sns.lmplot(x="humidity", y="temperature", hue="weather_type", data=weather)
